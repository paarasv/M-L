# %%
import pandas as pd
import numpy as np
stock_df=pd.read_csv("all_stocks_5yr.csv")
new1=stock_df.head(200)
new1.describe()
import numpy as np
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
numeric_cols = new1.select_dtypes(include=[np.number]).columns
new1_copy = new1.copy()
new1_copy[numeric_cols] = scaler.fit_transform(new1_copy[numeric_cols])
new1_copy[numeric_cols] 
import seaborn as sns
sns.pairplot(new1_copy[numeric_cols] )
